# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, CSVLogger, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras import backend as K
import json

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)

# Custom metrics
def iou(y_true, y_pred, smooth=0.5):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# Display Confusion Matrix as Image
def display_confusion_matrix_as_image(y_true, y_pred, class_names, save_path):
    cm = confusion_matrix(y_true, y_pred)
    cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_df, annot=True, fmt="d", cmap="YlGnBu")
    plt.title("Confusion Matrix")
    plt.ylabel("Actual Label")
    plt.xlabel("Predicted Label")
    plt.savefig(save_path)
    plt.close()
    print(f"Confusion matrix image saved at {save_path}")

# Prepare the data
train_root_path = r"E:\MalImg dataset\dataset_9010\dataset_9010\malimg_dataset\train"
val_root_path = r"E:\MalImg dataset\dataset_9010\dataset_9010\malimg_dataset\validation"

batches = ImageDataGenerator().flow_from_directory(directory=train_root_path, target_size=(64, 64), batch_size=10000)
imgs, labels = next(batches)
print(imgs.shape, labels.shape)

# Function to plot images with labels
def plots(ims, figsize=(20, 30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0, 2, 3, 1))
    f = plt.figure(figsize=figsize)
    cols = 10
    for i in range(0, 50):
        sp = f.add_subplot(rows, cols, i + 1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

plots(imgs, titles=labels)

# Calculate class distribution
classes = list(batches.class_indices.keys())
perc = (sum(labels) / labels.shape[0]) * 100
plt.xticks(rotation='vertical')
plt.bar(classes, perc)
plt.show()

# Split the data
x_train, x_test, y_train, y_test = train_test_split(imgs / 255.0, labels, test_size=0.3)
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")

num_classes = len(classes)

class NesTBlock(layers.Layer):
    def __init__(self, filters, kernel_size=3, strides=1):
        super(NesTBlock, self).__init__()
        self.conv1 = layers.Conv2D(filters, kernel_size, strides, padding="same", activation="relu")
        self.conv2 = layers.Conv2D(filters, kernel_size, strides, padding="same", activation="relu")
        self.pool = layers.MaxPooling2D(pool_size=(2, 2))

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        return self.pool(x)

def create_nest_classifier(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    x = NesTBlock(64)(inputs)
    x = NesTBlock(128)(x)
    x = NesTBlock(256)(x)
    x = NesTBlock(512)(x)
    x = layers.Flatten()(x)
    x = layers.Dense(2048, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(1024, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = keras.Model(inputs, outputs)
    return model

# Model parameters
input_shape = (64, 64, 3)
num_classes = len(classes)
learning_rate = 1e-3

nest_classifier = create_nest_classifier(input_shape=input_shape, num_classes=num_classes)

nest_classifier.compile(
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy", f1_score, specificity, sensitivity, iou]
)

# Callbacks
checkpoint = ModelCheckpoint("best_nest_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_delta=0.0001)
csv_logger = CSVLogger('NesT_Model.log')
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]

# Train the Model
history = nest_classifier.fit(
    x_train, y_train,
    batch_size=32,
    epochs=50,
    validation_split=0.2,
    callbacks=callbacks
)
nest_classifier.save("nest_model.keras")
print("Saved model to disk")

# Plot training & validation loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# Evaluate the Model and Print Results
print("Evaluate on test data")
results = nest_classifier.evaluate(x_test, y_test, batch_size=32)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")

# Print training accuracy
train_accuracy = history.history['accuracy'][-1]
val_accuracy = history.history['val_accuracy'][-1]
print(f"Training Accuracy: {train_accuracy}, Validation Accuracy: {val_accuracy}")

# Print loss and accuracy
train_loss = history.history['loss'][-1]
val_loss = history.history['val_loss'][-1]
print(f"Training Loss: {train_loss}, Validation Loss: {val_loss}")

# Make Predictions and Save Model to JSON
pred_x = nest_classifier.predict(x_test, verbose=0)
y_pred = np.argmax(pred_x, axis=1)
y_test2 = np.argmax(y_test, axis=1)

# Display Confusion Matrix as Image
display_confusion_matrix_as_image(y_test2, y_pred, classes, 'confusion_matrix_nest.png')

# Classification Report
report = classification_report(y_test2, y_pred, digits=3, output_dict=True)
df = pd.DataFrame(report).transpose().reset_index().rename(columns={"index": "class_label"})

# Review classification report
clf_rep = classification_report(y_test2, y_pred, digits=3)
print(clf_rep)

# Display aggregated values
options = ['accuracy', 'macro avg', 'weighted avg']
agg_df = df[df['class_label'].isin(options)]
print(agg_df)

# Save the model to JSON
model_json = nest_classifier.to_json()
with open("nest_model.json", "w") as json_file:
    json_file.write(model_json)
print("Saved model to JSON")

# Predict and Show Output for New Input Image
def prepare_image(img_path, target_size):
    img = load_img(img_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    return img_array

def predict_image(model, img_array, class_names):
    pred = model.predict(img_array)
    pred_class = np.argmax(pred, axis=1)
    return class_names[pred_class[0]]

# User input image path
img_path = r"E:\F boliom\Downloads\00a6163bad908d7f396e3c13a989bfd4.png"  # Replace with the path to the image
img_array = prepare_image(img_path, (64, 64))

# Show the image
img = load_img(img_path)
plt.imshow(img)
plt.axis('off')
plt.show()

# Predict and display the result
predicted_class = predict_image(nest_classifier, img_array, classes)
print(f"The predicted class for the input image is: {predicted_class}")
# Out:
# TensorFlow version: 2.16.1
# Keras version: 3.3.3
# Found 8404 images belonging to 25 classes.
# (8404, 64, 64, 3) (8404, 25)
# x_train shape: (5882, 64, 64, 3) - y_train shape: (5882, 25)
# x_test shape: (2522, 64, 64, 3) - y_test shape: (2522, 25)
# WARNING:tensorflow:From C:\Users\Hp\pythonset\lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3684 - f1_score: 0.2609 - iou: 0.1549 - loss: 2.1874 - sensitivity: 0.2070 - specificity: 0.9938
# Epoch 1: val_accuracy improved from -inf to 0.74936, saving model to best_nest_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 297s 2s/step - accuracy: 0.3693 - f1_score: 0.2621 - iou: 0.1555 - loss: 2.1837 - sensitivity: 0.2081 - specificity: 0.9938 - val_accuracy: 0.7494 - val_f1_score: 0.7761 - val_iou: 0.4587 - val_loss: 0.8031 - val_sensitivity: 0.7046 - val_specificity: 0.9954 - learning_rate: 0.0010
# Epoch 2/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7806 - f1_score: 0.7910 - iou: 0.5438 - loss: 0.7124 - sensitivity: 0.7365 - specificity: 0.9949
# Epoch 2: val_accuracy improved from 0.74936 to 0.90739, saving model to best_nest_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 221s 1s/step - accuracy: 0.7809 - f1_score: 0.7914 - iou: 0.5443 - loss: 0.7115 - sensitivity: 0.7369 - specificity: 0.9949 - val_accuracy: 0.9074 - val_f1_score: 0.9086 - val_iou: 0.7748 - val_loss: 0.3047 - val_sensitivity: 0.8755 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 3/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9185 - f1_score: 0.9222 - iou: 0.7915 - loss: 0.2792 - sensitivity: 0.8999 - specificity: 0.9979
# Epoch 3: val_accuracy improved from 0.90739 to 0.92523, saving model to best_nest_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.9185 - f1_score: 0.9222 - iou: 0.7915 - loss: 0.2792 - sensitivity: 0.8999 - specificity: 0.9979 - val_accuracy: 0.9252 - val_f1_score: 0.9250 - val_iou: 0.8043 - val_loss: 0.2114 - val_sensitivity: 0.8998 - val_specificity: 0.9981 - learning_rate: 0.0010
# Epoch 4/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9365 - f1_score: 0.9384 - iou: 0.8330 - loss: 0.2023 - sensitivity: 0.9227 - specificity: 0.9982
# Epoch 4: val_accuracy improved from 0.92523 to 0.94308, saving model to best_nest_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9365 - f1_score: 0.9384 - iou: 0.8331 - loss: 0.2022 - sensitivity: 0.9227 - specificity: 0.9982 - val_accuracy: 0.9431 - val_f1_score: 0.9475 - val_iou: 0.8730 - val_loss: 0.1707 - val_sensitivity: 0.9368 - val_specificity: 0.9983 - learning_rate: 0.0010
# Epoch 5/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9474 - f1_score: 0.9477 - iou: 0.8687 - loss: 0.1681 - sensitivity: 0.9362 - specificity: 0.9984
# Epoch 5: val_accuracy improved from 0.94308 to 0.96432, saving model to best_nest_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.9474 - f1_score: 0.9477 - iou: 0.8687 - loss: 0.1680 - sensitivity: 0.9363 - specificity: 0.9984 - val_accuracy: 0.9643 - val_f1_score: 0.9580 - val_iou: 0.8963 - val_loss: 0.1142 - val_sensitivity: 0.9446 - val_specificity: 0.9989 - learning_rate: 0.0010
# Epoch 6/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 944ms/step - accuracy: 0.9653 - f1_score: 0.9650 - iou: 0.9050 - loss: 0.1118 - sensitivity: 0.9571 - specificity: 0.9989
# Epoch 6: val_accuracy did not improve from 0.96432
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.9653 - f1_score: 0.9650 - iou: 0.9050 - loss: 0.1119 - sensitivity: 0.9570 - specificity: 0.9989 - val_accuracy: 0.9626 - val_f1_score: 0.9614 - val_iou: 0.9103 - val_loss: 0.1370 - val_sensitivity: 0.9533 - val_specificity: 0.9988 - learning_rate: 0.0010
# Epoch 7/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 943ms/step - accuracy: 0.9752 - f1_score: 0.9755 - iou: 0.9325 - loss: 0.0791 - sensitivity: 0.9693 - specificity: 0.9993
# Epoch 7: val_accuracy improved from 0.96432 to 0.96517, saving model to best_nest_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9752 - f1_score: 0.9755 - iou: 0.9325 - loss: 0.0791 - sensitivity: 0.9693 - specificity: 0.9993 - val_accuracy: 0.9652 - val_f1_score: 0.9664 - val_iou: 0.9228 - val_loss: 0.1306 - val_sensitivity: 0.9641 - val_specificity: 0.9987 - learning_rate: 0.0010
# Epoch 8/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9803 - f1_score: 0.9804 - iou: 0.9429 - loss: 0.0719 - sensitivity: 0.9775 - specificity: 0.9993
# Epoch 8: val_accuracy did not improve from 0.96517
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.9803 - f1_score: 0.9804 - iou: 0.9429 - loss: 0.0720 - sensitivity: 0.9775 - specificity: 0.9993 - val_accuracy: 0.9558 - val_f1_score: 0.9584 - val_iou: 0.9093 - val_loss: 0.1323 - val_sensitivity: 0.9516 - val_specificity: 0.9986 - learning_rate: 0.0010
# Epoch 9/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.9607 - f1_score: 0.9630 - iou: 0.9112 - loss: 0.1202 - sensitivity: 0.9566 - specificity: 0.9988
# Epoch 9: val_accuracy did not improve from 0.96517
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9607 - f1_score: 0.9630 - iou: 0.9113 - loss: 0.1202 - sensitivity: 0.9566 - specificity: 0.9988 - val_accuracy: 0.9609 - val_f1_score: 0.9619 - val_iou: 0.9008 - val_loss: 0.1239 - val_sensitivity: 0.9514 - val_specificity: 0.9989 - learning_rate: 0.0010
# Epoch 10/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 979ms/step - accuracy: 0.9754 - f1_score: 0.9762 - iou: 0.9368 - loss: 0.0773 - sensitivity: 0.9710 - specificity: 0.9992
# Epoch 10: val_accuracy improved from 0.96517 to 0.96602, saving model to best_nest_model.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9754 - f1_score: 0.9762 - iou: 0.9367 - loss: 0.0774 - sensitivity: 0.9710 - specificity: 0.9992 - val_accuracy: 0.9660 - val_f1_score: 0.9651 - val_iou: 0.9232 - val_loss: 0.1387 - val_sensitivity: 0.9615 - val_specificity: 0.9987 - learning_rate: 0.0010
# Epoch 11/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9867 - f1_score: 0.9866 - iou: 0.9637 - loss: 0.0433 - sensitivity: 0.9843 - specificity: 0.9995
# Epoch 11: val_accuracy improved from 0.96602 to 0.97196, saving model to best_nest_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9868 - f1_score: 0.9866 - iou: 0.9637 - loss: 0.0433 - sensitivity: 0.9843 - specificity: 0.9995 - val_accuracy: 0.9720 - val_f1_score: 0.9719 - val_iou: 0.9375 - val_loss: 0.1137 - val_sensitivity: 0.9691 - val_specificity: 0.9990 - learning_rate: 2.0000e-04
# Epoch 12/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.9959 - f1_score: 0.9959 - iou: 0.9820 - loss: 0.0211 - sensitivity: 0.9953 - specificity: 0.9999
# Epoch 12: val_accuracy improved from 0.97196 to 0.97451, saving model to best_nest_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9958 - f1_score: 0.9959 - iou: 0.9820 - loss: 0.0211 - sensitivity: 0.9953 - specificity: 0.9999 - val_accuracy: 0.9745 - val_f1_score: 0.9732 - val_iou: 0.9412 - val_loss: 0.1167 - val_sensitivity: 0.9691 - val_specificity: 0.9991 - learning_rate: 2.0000e-04
# Epoch 13/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9955 - f1_score: 0.9959 - iou: 0.9855 - loss: 0.0141 - sensitivity: 0.9954 - specificity: 0.9999
# Epoch 13: val_accuracy did not improve from 0.97451
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - accuracy: 0.9955 - f1_score: 0.9959 - iou: 0.9855 - loss: 0.0141 - sensitivity: 0.9954 - specificity: 0.9999 - val_accuracy: 0.9745 - val_f1_score: 0.9745 - val_iou: 0.9435 - val_loss: 0.1347 - val_sensitivity: 0.9725 - val_specificity: 0.9990 - learning_rate: 2.0000e-04
# Epoch 14/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 986ms/step - accuracy: 0.9962 - f1_score: 0.9963 - iou: 0.9862 - loss: 0.0113 - sensitivity: 0.9960 - specificity: 0.9999
# Epoch 14: val_accuracy did not improve from 0.97451
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9962 - f1_score: 0.9963 - iou: 0.9862 - loss: 0.0113 - sensitivity: 0.9960 - specificity: 0.9999 - val_accuracy: 0.9728 - val_f1_score: 0.9733 - val_iou: 0.9431 - val_loss: 0.1326 - val_sensitivity: 0.9717 - val_specificity: 0.9990 - learning_rate: 2.0000e-04
# Epoch 15/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9986 - f1_score: 0.9980 - iou: 0.9921 - loss: 0.0054 - sensitivity: 0.9973 - specificity: 0.9999
# Epoch 15: val_accuracy did not improve from 0.97451
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - accuracy: 0.9986 - f1_score: 0.9980 - iou: 0.9921 - loss: 0.0054 - sensitivity: 0.9973 - specificity: 0.9999 - val_accuracy: 0.9737 - val_f1_score: 0.9740 - val_iou: 0.9435 - val_loss: 0.1349 - val_sensitivity: 0.9736 - val_specificity: 0.9989 - learning_rate: 2.0000e-04
# Epoch 16/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9968 - f1_score: 0.9968 - iou: 0.9888 - loss: 0.0178 - sensitivity: 0.9968 - specificity: 0.9999
# Epoch 16: val_accuracy improved from 0.97451 to 0.97536, saving model to best_nest_model.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9968 - f1_score: 0.9968 - iou: 0.9889 - loss: 0.0178 - sensitivity: 0.9968 - specificity: 0.9999 - val_accuracy: 0.9754 - val_f1_score: 0.9748 - val_iou: 0.9472 - val_loss: 0.1397 - val_sensitivity: 0.9736 - val_specificity: 0.9990 - learning_rate: 2.0000e-04
# Epoch 17/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9986 - f1_score: 0.9986 - iou: 0.9944 - loss: 0.0048 - sensitivity: 0.9986 - specificity: 0.9999
# Epoch 17: val_accuracy did not improve from 0.97536
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9986 - f1_score: 0.9986 - iou: 0.9944 - loss: 0.0048 - sensitivity: 0.9986 - specificity: 0.9999 - val_accuracy: 0.9754 - val_f1_score: 0.9748 - val_iou: 0.9470 - val_loss: 0.1463 - val_sensitivity: 0.9736 - val_specificity: 0.9990 - learning_rate: 4.0000e-05
# Epoch 18/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9995 - f1_score: 0.9996 - iou: 0.9966 - loss: 0.0022 - sensitivity: 0.9995 - specificity: 1.0000
# Epoch 18: val_accuracy did not improve from 0.97536
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9995 - f1_score: 0.9996 - iou: 0.9966 - loss: 0.0022 - sensitivity: 0.9995 - specificity: 1.0000 - val_accuracy: 0.9745 - val_f1_score: 0.9748 - val_iou: 0.9465 - val_loss: 0.1523 - val_sensitivity: 0.9736 - val_specificity: 0.9990 - learning_rate: 4.0000e-05
# Epoch 19/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9991 - f1_score: 0.9993 - iou: 0.9960 - loss: 0.0039 - sensitivity: 0.9991 - specificity: 1.0000
# Epoch 19: val_accuracy did not improve from 0.97536
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - accuracy: 0.9991 - f1_score: 0.9993 - iou: 0.9960 - loss: 0.0039 - sensitivity: 0.9991 - specificity: 1.0000 - val_accuracy: 0.9745 - val_f1_score: 0.9748 - val_iou: 0.9474 - val_loss: 0.1561 - val_sensitivity: 0.9736 - val_specificity: 0.9990 - learning_rate: 4.0000e-05
# Epoch 20/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - accuracy: 0.9989 - f1_score: 0.9989 - iou: 0.9959 - loss: 0.0033 - sensitivity: 0.9989 - specificity: 1.0000
# Epoch 20: val_accuracy did not improve from 0.97536
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.9989 - f1_score: 0.9989 - iou: 0.9959 - loss: 0.0033 - sensitivity: 0.9989 - specificity: 1.0000 - val_accuracy: 0.9754 - val_f1_score: 0.9748 - val_iou: 0.9473 - val_loss: 0.1594 - val_sensitivity: 0.9736 - val_specificity: 0.9990 - learning_rate: 4.0000e-05
# Epoch 21/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 987ms/step - accuracy: 0.9997 - f1_score: 0.9997 - iou: 0.9963 - loss: 0.0039 - sensitivity: 0.9997 - specificity: 1.0000
# Epoch 21: val_accuracy did not improve from 0.97536
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9997 - f1_score: 0.9997 - iou: 0.9963 - loss: 0.0039 - sensitivity: 0.9997 - specificity: 1.0000 - val_accuracy: 0.9754 - val_f1_score: 0.9752 - val_iou: 0.9453 - val_loss: 0.1646 - val_sensitivity: 0.9744 - val_specificity: 0.9990 - learning_rate: 4.0000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Saved model to disk
# Evaluate on test data
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 263ms/step - accuracy: 0.9648 - f1_score: 0.9658 - iou: 0.9319 - loss: 0.1273 - sensitivity: 0.9647 - specificity: 0.9986
# Test Loss: 0.1297677606344223, Test Accuracy: 0.9662966132164001
# Training Accuracy: 0.9995748996734619, Validation Accuracy: 0.9753611087799072
# Training Loss: 0.0038392581045627594, Validation Loss: 0.16463300585746765
# Confusion matrix image saved at confusion_matrix_nest.png
#               precision    recall  f1-score   support
#
#            0      0.973     1.000     0.986        36
#            1      0.966     1.000     0.982        28
#            2      1.000     0.999     0.999       835
#            3      1.000     1.000     1.000       466
#            4      1.000     0.976     0.988        42
#            5      0.957     1.000     0.978        22
#            6      0.800     0.432     0.561        37
#            7      0.667     0.531     0.591        49
#            8      1.000     1.000     1.000        44
#            9      0.980     1.000     0.990        49
#           10      1.000     0.988     0.994        81
#           11      0.991     1.000     0.996       116
#           12      0.982     1.000     0.991        54
#           13      1.000     0.978     0.989        46
#           14      0.970     0.941     0.955        34
#           15      1.000     0.950     0.974        40
#           16      1.000     0.974     0.987        39
#           17      1.000     1.000     1.000        28
#           18      0.875     0.897     0.886        39
#           19      0.950     1.000     0.974        19
#           20      0.250     0.529     0.340        17
#           21      0.395     0.455     0.423        33
#           22      0.964     0.982     0.973       110
#           23      0.950     1.000     0.974        19
#           24      1.000     1.000     1.000       239
#
#     accuracy                          0.966      2522
#    macro avg      0.907     0.905     0.901      2522
# weighted avg      0.971     0.966     0.967      2522
#
#      class_label  precision    recall  f1-score      support
# 25      accuracy   0.966297  0.966297  0.966297     0.966297
# 26     macro avg   0.906747  0.905308  0.901278  2522.000000
# 27  weighted avg   0.970643  0.966297  0.967099  2522.000000
# Saved model to JSON
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# The predicted class for the input image is: Fakerean
